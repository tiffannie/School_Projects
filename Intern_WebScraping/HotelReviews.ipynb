# %%
# Specify url: url
url1 = 'https://www.yelp.com/biz/sheraton-waikiki-honolulu?osq=Hotels'

# Package the request, send the request and catch the response: r
r1 = requests.get(url1)

# Extracts the response as html: html_doc
html_doc1 = r1.text

# Create a BeautifulSoup object from the HTML: soup
soup1 = BeautifulSoup(html_doc1)

# Prettify the BeautifulSoup object: pretty_soup
pretty_soup1 = soup1.prettify()

# %%
#print title of webpage
webpage_title1 = soup1.title
print webpage_title1
print soup1
# Out:
# <title>Sheraton Waikiki - 1482 Photos &amp; 604 Reviews - Hotels - 2255 Kalakaua Ave, Waikiki, Honolulu, HI - Phone Number - Yelp</title>
# <!DOCTYPE HTML>
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]--><!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]--><!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]--><!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <script>            window.yPageStart = new Date().getTime();
# </script>
# <script>            var initialVisibilityState = document.webkitVisibilityState;
#
#                 yPerfTimings = [];
#
# ...

# %%
#get test of webpage
webpage_text1 = soup1.get_text()

print(webpage_text)
# Out:
#
#
#             window.yPageStart = new Date().getTime();
#
#             var initialVisibilityState = document.webkitVisibilityState;
#
#                 yPerfTimings = [];
#
#                 ySitRepParams = {"b3Sampled": null, "edgeStartTime": 1497943915146236, "site": "main", "uniqueRequestID": "9971cdee7cf8e1b4", "isLoggedIn": false, "clientIP": "66.27.205.32", "servlet": "biz_details", "zipkinTraceID": "9971cdee7cf8e1b4", "datacenter": "us-west-1", "cfRayID": null, "serverStartTime": 1497943915153, "action": "default", "yuv_record": "vUHS9WOjEGxexXdNs2GIIA-tDyJMQ1bZ9HPOvvbJpWMcBEjZocaYqVCHzLj5ntrbbWV8elMK65qBiHu-SyDvdJFKUEVj-kfT"};
#                 window.ySitRepParams['initialVisibilityState'] = initialVisibilityState;
# ...

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# %%
# Specify url: url
url = 'https://www.travelocity.com/Oahu-Hotels-Turtle-Bay-Resort.h470837.Hotel-Information?chkin=6%2F19%2F2017&chkout=6%2F20%2F2017&rm1=a1&regionId=8500&sort=guestRating&hwrqCacheKey=fc50e680-1d03-4cb9-83dd-75572e23c12cHWRQ1497941335604&vip=false&c=34779fd8-7af8-418a-83bc-ce3c39f5a16c&&exp_dp=228.66&exp_ts=1497941329351&exp_curr=USD&exp_pg=HSR'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extracts the response as html: html_doc
html_doc = r.text

# Create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Prettify the BeautifulSoup object: pretty_soup
pretty_soup = soup.prettify()

# %%
#print title of webpage
webpage_title = soup.title
print webpage_title
# Out:
# <title>    Book Turtle Bay Resort | Kahuku Hotel Deals
# </title>

# %%
#get test of webpage
webpage_text = soup.get_text()

#print(webpage_text)

# %%
import re

#soup = BeautifulSoup.BeautifulSoup('<html><body><div id="reviews-content">')
reviews = soup.find("div", {"id": "reviews-content"})
reviews1 = soup.findAll("section", {"class": "segmented-list", "class":"cf"})
reviews2 = soup.find_all('details')
type(reviews2)
for com in reviews2:
    print(com)

for comment in soup.findAll(attrs={'class': re.compile(r".*\segmented-list cf\b.*")}):
    print comment

# %%
#getting hyperlinks
# Find all 'a' tags (which define hyperlinks): a_tags
#<a> hyperlinks in html hav this tag
a_tags = soup.find_all('a')
type(a_tags)
#for link in a_tags:
 #   print(link.get('href'))
#for link in a_tags:
 #   print(link)
# Out:
# bs4.element.ResultSet
